# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujashettar/tanuja/blob/main/ASSIGNMENT_lV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Password Strength Checker Function

# %%
def check_password_strength(password):
    if len(password) < 8:
        return "Weak Password: Must contain at least 8 characters."

    has_digit = False
    has_special = False
    special_chars = "!@#$%^&*()_+-=[]{}|;:',.<>?/"

    for ch in password:
        if ch.isdigit():
            has_digit = True
        if ch in special_chars:
            has_special = True

    if has_digit and has_special:
        return "Strong Password"
    else:
        return "Weak Password: Must contain at least one digit and one special character."


# Example usage
password = "Pass@123"
result = check_password_strength(password)
print(result)
# Out:
# Strong Password
