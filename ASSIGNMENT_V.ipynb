# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujashettar/tanuja/blob/main/ASSIGNMENT_V.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Product Discount Function

# %%
def calculate_discount(price, customer_type):
    if customer_type == "Regular":
        discount = 0.05
    elif customer_type == "Premium":
        discount = 0.15
    elif customer_type == "Employee":
        discount = 0.25
    else:
        discount = 0

    final_price = price - (price * discount)
    return final_price


# Example usage
price = 2000
customer_type = "Premium"

final_amount = calculate_discount(price, customer_type)
print("Final Price after Discount: ₹", final_amount)
# Out:
# Final Price after Discount: ₹ 1700.0
